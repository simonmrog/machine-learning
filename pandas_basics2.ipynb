# %%
# IMPORTING PACKAGES 

# shows in jupyter notebook
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from datetime import datetime
import dateutil.parser

# this allows us to show several ouputs in one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# display only 80 columns
pd.set_option("display.max_columns", 80)
pd.set_option("expand_frame_repr", True)

# %%
# READING DATASET
#dataset downloaded from http://build.kiva.org (900MB compressed)

path = "kiva_data/"
filename = "loans.csv"

df = pd.read_csv(path + filename, nrows = 10000)

# %%
#shows three random samples of the data
df.sample(n = 3)
# Out:
#       LOAN_ID LOAN_NAME ORIGINAL_LANGUAGE  \
# 7972   894916   Cecelia           English
# 5692  1119372   Hamidah           English
# 8848   991150     Zahid           English
#
#                                             DESCRIPTION  \
# 7972  Cecelia works hard to support her family. Cece...
# 5692  Good day, lenders!  Meet one of KSPPS BMI’s cl...
# 8848  Zahid is 57 years old. He is refugee, living i...
#
#                                  DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 7972  Cecelia works hard to support her family. Cece...            450
# 5692  Good day, lenders!  Meet one of KSPPS BMI’s cl...            175
# 8848  Zahid is 57 years old. He is refugee, living i...           1150
#
#       LOAN_AMOUNT  STATUS  IMAGE_ID  VIDEO_ID              ACTIVITY_NAME  \
# 7972          450  funded   1894354       NaN      Food Production/Sales
# 5692          175  funded   2257487       NaN  Personal Housing Expenses
# 8848         1150  funded   2045985       NaN                  Livestock
#
#       SECTOR_NAME                                           LOAN_USE  \
# 7972         Food  to buy ingredients like meat, fish, chicken me...
# 5692      Housing         To build a clean water source at her home.
# 8848  Agriculture                                 to purchase sheep
#
#      COUNTRY_CODE COUNTRY_NAME          TOWN_NAME CURRENCY_POLICY  \
# 7972           PH  Philippines  Roxas City, Capiz          shared
# 5692           ID    Indonesia          Tangerang          shared
# 8848           AZ   Azerbaijan          Bilasuvar          shared
#
#       CURRENCY_EXCHANGE_COVERAGE_RATE CURRENCY  PARTNER_ID  \
# 7972                              0.1      PHP         145
# 5692                              0.1      IDR         406
# 8848                              0.1      AZN          56
#
#                         POSTED_TIME        PLANNED_EXPIRATION_TIME  \
# 7972  2015-06-01 05:01:37.000 +0000  2015-07-03 17:50:03.000 +0000
# 5692  2016-07-20 02:42:01.000 +0000  2016-08-28 01:10:03.000 +0000
# 8848  2015-12-07 17:53:14.000 +0000  2016-01-08 18:30:02.000 +0000
#
#                       DISBURSE_TIME                    RAISED_TIME  \
# 7972  2015-05-05 07:00:00.000 +0000  2015-06-04 11:30:53.000 +0000
# 5692  2016-06-30 07:00:00.000 +0000  2016-07-31 04:06:20.000 +0000
# 8848  2015-11-26 08:00:00.000 +0000  2016-01-08 18:17:23.000 +0000
#
#       LENDER_TERM  NUM_LENDERS_TOTAL  NUM_JOURNAL_ENTRIES  NUM_BULK_ENTRIES  \
# 7972            7                  2                    1                 1
# 5692           37                  6                    1                 1
# 8848           20                 39                    4                 2
#
#                                                    TAGS BORROWER_NAMES  \
# 7972                                                NaN        Cecelia
# 5692  #Elderly, #Eco-friendly, #Health and Sanitatio...        Hamidah
# 8848        #Animals, #Elderly, #Refugee, user_favorite          Zahid
#
#      BORROWER_GENDERS BORROWER_PICTURED REPAYMENT_INTERVAL DISTRIBUTION_MODEL
# 7972           female              true          irregular      field_partner
# 5692           female              true          irregular      field_partner
# 8848             male              true            monthly      field_partner

# %%
#number of columns shown as a list
df.columns.tolist()
# Out:
# ['LOAN_ID',
#  'LOAN_NAME',
#  'ORIGINAL_LANGUAGE',
#  'DESCRIPTION',
#  'DESCRIPTION_TRANSLATED',
#  'FUNDED_AMOUNT',
#  'LOAN_AMOUNT',
#  'STATUS',
#  'IMAGE_ID',
#  'VIDEO_ID',
#  'ACTIVITY_NAME',
#  'SECTOR_NAME',
#  'LOAN_USE',
#  'COUNTRY_CODE',
#  'COUNTRY_NAME',
#  'TOWN_NAME',
#  'CURRENCY_POLICY',
#  'CURRENCY_EXCHANGE_COVERAGE_RATE',
#  'CURRENCY',
#  'PARTNER_ID',
#  'POSTED_TIME',
#  'PLANNED_EXPIRATION_TIME',
#  'DISBURSE_TIME',
#  'RAISED_TIME',
#  'LENDER_TERM',
#  'NUM_LENDERS_TOTAL',
#  'NUM_JOURNAL_ENTRIES',
#  'NUM_BULK_ENTRIES',
#  'TAGS',
#  'BORROWER_NAMES',
#  'BORROWER_GENDERS',
#  'BORROWER_PICTURED',
#  'REPAYMENT_INTERVAL',
#  'DISTRIBUTION_MODEL']

# %%
# shows the data type of the column "LOAD_ID"
df["LOAN_ID"].dtype
# Out:
# dtype('int64')

# %%
# number of observations and features (rows and columns) using .shape function
df.shape
print ("There are "  + str(df.shape[0]) + " observations and " + str(df.shape[1]) + " features")
# Out:
# (10000, 34)
# There are 10000 observations and 34 features

# %%
#describing categorical features (string)

#filters for all columns that are a data type object (string in this case)
categorical = df.dtypes[df.dtypes == "object"].index

#random row of our new filtered dataset
df[categorical].sample()

#getting summary statistics from our new filtered dataset
df[categorical].describe()
#count: is the number of of active fields (not empty)
#unique: is the number of fields that are unique (not repeated)
#top: most popular value in the feature
#freq: how frequent is the most popular value in the feature
# Out:
#      LOAN_NAME ORIGINAL_LANGUAGE  \
# 2042    Pacita           English
#
#                                             DESCRIPTION  \
# 2042  Pacita is 60 years old and married with six ch...
#
#                                  DESCRIPTION_TRANSLATED  STATUS ACTIVITY_NAME  \
# 2042  Pacita is 60 years old and married with six ch...  funded       Farming
#
#       SECTOR_NAME                                     LOAN_USE COUNTRY_CODE  \
# 2042  Agriculture  to buy fertilizers and other farm supplies.           PH
#
#      COUNTRY_NAME                      TOWN_NAME CURRENCY_POLICY CURRENCY  \
# 2042  Philippines  Himamaylan, Negros Occidental          shared      PHP
#
#                         POSTED_TIME        PLANNED_EXPIRATION_TIME  \
# 2042  2017-03-20 04:19:54.000 +0000  2017-04-22 04:40:04.000 +0000
#
#                       DISBURSE_TIME                    RAISED_TIME  \
# 2042  2017-02-27 08:00:00.000 +0000  2017-03-23 15:22:58.000 +0000
#
#                             TAGS BORROWER_NAMES BORROWER_GENDERS  \
# 2042  #Woman Owned Biz, #Elderly         Pacita           female
#
#      BORROWER_PICTURED REPAYMENT_INTERVAL DISTRIBUTION_MODEL
# 2042              true          irregular      field_partner
#               LOAN_NAME ORIGINAL_LANGUAGE  \
# count              9681              9708
# unique             6891                 7
# top     Anonymous Group           English
# freq                 62              6666
#
#                                               DESCRIPTION  \
# count                                                9708
# unique                                               9708
# top     Agée de 37 ans, Louise est mariée  .Le nombre ...
# freq                                                    1
#
#                                    DESCRIPTION_TRANSLATED  STATUS  \
# count                                                6407   10000
# unique                                               6407       4
# top     Gloria is a married woman with four children. ...  funded
# freq                                                    1    9559
#
#         ACTIVITY_NAME  SECTOR_NAME  \
# count           10000        10000
# unique            144           15
# top     General Store  Agriculture
# freq              997         2387
#
#                                           LOAN_USE COUNTRY_CODE COUNTRY_NAME  \
# count                                         9708        10000        10000
# unique                                        8570           75           75
# top     to build a sanitary toilet for her family.           PH  Philippines
# freq                                            51         2487         2487
#
#        TOWN_NAME CURRENCY_POLICY CURRENCY                    POSTED_TIME  \
# count       8928           10000    10000                          10000
# unique      2124               2       64                          10000
# top       Lahore          shared      PHP  2016-09-22 05:53:50.000 +0000
# freq          92            8688     2487                              1
#
#               PLANNED_EXPIRATION_TIME                  DISBURSE_TIME  \
# count                            9628                          10000
# unique                           9348                           1261
# top     2013-03-03 09:18:09.000 +0000  2014-01-22 08:00:00.000 +0000
# freq                                3                             41
#
#                           RAISED_TIME           TAGS BORROWER_NAMES  \
# count                            9567           4274           9681
# unique                           9487           1898           7049
# top     2017-12-13 03:41:04.000 +0000  user_favorite         Evelyn
# freq                                3            401             29
#
#        BORROWER_GENDERS BORROWER_PICTURED REPAYMENT_INTERVAL  \
# count              9708              9708              10000
# unique              327               196                  3
# top              female              true            monthly
# freq               6399              8402               5083
#
#        DISTRIBUTION_MODEL
# count               10000
# unique                  2
# top         field_partner
# freq                 9991
